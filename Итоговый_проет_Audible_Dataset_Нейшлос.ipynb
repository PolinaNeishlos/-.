# %% [markdown]
# <a href="https://colab.research.google.com/github/PolinaNeishlos/-./blob/main/%D0%98%D1%82%D0%BE%D0%B3%D0%BE%D0%B2%D1%8B%D0%B9_%D0%BF%D1%80%D0%BE%D0%B5%D1%82_Audible_Dataset_%D0%9D%D0%B5%D0%B9%D1%88%D0%BB%D0%BE%D1%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# вставила файл, который ранее по максимуму отформатировала в google sheets

# %%
import pandas as pd
df = pd.read_csv('/content/neishlos.csv')
df
# Out:
#                                             name  \
# 0                     Geronimo Stilton #11 & #12
# 1                               The Burning Maze
# 2                                   The Deep End
# 3                           Daughter of the Deep
# 4     The Lightning Thief: Percy Jackson, Book 1
# ...                                          ...
# 4994                    Rapunzel and Other Tales
# 4995                The School for Good and Evil
# 4996                                  The Rumour
# 4997                   Aesop's Fables Reimagined
# 4998            Al negozio di giocattoli antichi
#
#                                              author            narrator  \
# 0                                   GeronimoStilton          BillLobely
# 1                                       RickRiordan       RobbieDaymond
# 2                                        JeffKinney          DanRussell
# 3                                       RickRiordan      SoneelaNankani
# ...

# %%
df.isna().sum()
# Out:
# name               0
# author             0
# narrator           0
# time               0
# release_date       0
# language           0
# price              0
# stars              0
# ratings         4458
# dtype: int64

# %% [markdown]
# проверила, что пропущенные значения есть в колонке ratings

# %%
df['ratings'].value_counts(dropna=False)
# Out:
# NaN      4458
# 1.0       180
# 2.0        89
# 3.0        43
# 4.0        41
# 5.0        24
# 7.0        22
# 6.0        21
# 9.0        16
# 8.0        13
# 12.0       11
# 11.0       11
# 10.0        7
# 20.0        4
# 14.0        4
# 28.0        3
# 25.0        3
# 17.0        3
# 15.0        3
# 27.0        3
# 18.0        2
# 37.0        2
# 41.0        2
# 13.0        2
# 32.0        2
# 181.0       2
# 19.0        2
# 16.0        2
# 57.0        1
# 93.0        1
# 100.0       1
# 24.0        1
# 46.0        1
# 53.0        1
# 52.0        1
# 31.0        1
# 26.0        1
# 51.0        1
# 91.0        1
# 34.0        1
# 81.0        1
# 21.0        1
# 101.0       1
# 47.0        1
# 79.0        1
# 33.0        1
# 130.0       1
# 58.0        1
# 50.0        1
# 72.0        1
# 38.0        1
# 96.0        1
# Name: ratings, dtype: int64

# %% [markdown]
# просмотр пропусков

# %%
df[df['ratings'].isna()]
# Out:
#                                                    name  \
# 34    14 Short Stories Bundle for Kids: Adventure, S...
# 50                             A Bear Called Paddington
# 51               Gregor and the Curse of the Warmbloods
# 61                                    Across the Desert
# 62                    Unicorn Academy: Aisha and Silver
# ...                                                 ...
# 4990                                     Disney - Pixar
# 4992               Brothers Grimm Fairy Tales Revisited
# 4994                           Rapunzel and Other Tales
# 4997                          Aesop's Fables Reimagined
# 4998                   Al negozio di giocattoli antichi
#
#                                              author  \
# 34                                   NayomiPhillips
# 50                                      MichaelBond
# 51                                   SuzanneCollins
# 61                                     DustiBowling
# ...

# %% [markdown]
# смотрим, сколько процентов занимают пропуски

# %%
df['ratings'].value_counts(dropna=False, normalize = True)
# Out:
# NaN      0.891778
# 1.0      0.036007
# 2.0      0.017804
# 3.0      0.008602
# 4.0      0.008202
# 5.0      0.004801
# 7.0      0.004401
# 6.0      0.004201
# 9.0      0.003201
# 8.0      0.002601
# 12.0     0.002200
# 11.0     0.002200
# 10.0     0.001400
# 20.0     0.000800
# 14.0     0.000800
# 28.0     0.000600
# 25.0     0.000600
# 17.0     0.000600
# 15.0     0.000600
# 27.0     0.000600
# 18.0     0.000400
# 37.0     0.000400
# 41.0     0.000400
# 13.0     0.000400
# 32.0     0.000400
# 181.0    0.000400
# 19.0     0.000400
# 16.0     0.000400
# 57.0     0.000200
# 93.0     0.000200
# 100.0    0.000200
# 24.0     0.000200
# 46.0     0.000200
# 53.0     0.000200
# 52.0     0.000200
# 31.0     0.000200
# 26.0     0.000200
# 51.0     0.000200
# 91.0     0.000200
# 34.0     0.000200
# 81.0     0.000200
# 21.0     0.000200
# 101.0    0.000200
# 47.0     0.000200
# 79.0     0.000200
# 33.0     0.000200
# 130.0    0.000200
# 58.0     0.000200
# 50.0     0.000200
# 72.0     0.000200
# ...

# %%
df['ratings'].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['ratings'].mean()
# Out:
# 7.896487985212569

# %% [markdown]
# Так как пропусков больше 40%, колонку можно удалить

# %%
df.drop('ratings', axis=1)
# Out:
#                                             name  \
# 0                     Geronimo Stilton #11 & #12
# 1                               The Burning Maze
# 2                                   The Deep End
# 3                           Daughter of the Deep
# 4     The Lightning Thief: Percy Jackson, Book 1
# ...                                          ...
# 4994                    Rapunzel and Other Tales
# 4995                The School for Good and Evil
# 4996                                  The Rumour
# 4997                   Aesop's Fables Reimagined
# 4998            Al negozio di giocattoli antichi
#
#                                              author            narrator  \
# 0                                   GeronimoStilton          BillLobely
# 1                                       RickRiordan       RobbieDaymond
# 2                                        JeffKinney          DanRussell
# 3                                       RickRiordan      SoneelaNankani
# ...

# %%
df['stars'].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['stars'].mean()
# Out:
# 0.5027005401080216
